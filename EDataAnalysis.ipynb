# %% [markdown]
# <a href="https://colab.research.google.com/github/NetzwerkPriyanka8/ML_Project_Repo/blob/main/EDataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ED Analytics

# %% [markdown]
# #Importing the libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats

# %% [markdown]
# #Reading the Data

# %%
df = pd.read_csv('/content/automobile (1).csv')

# %% [markdown]
# #Displaying the first 5 rows of the dataset

# %%
df.head()
# Out:
#    symboling  normalized-losses         make  ... horsepower-binned diesel gas
# 0          3                122  alfa-romero  ...            Medium      0   1
# 1          3                122  alfa-romero  ...            Medium      0   1
# 2          1                122  alfa-romero  ...            Medium      0   1
# 3          2                164         audi  ...            Medium      0   1
# 4          2                164         audi  ...            Medium      0   1
#
# [5 rows x 29 columns]

# %% [markdown]
# #Describe method

# %%
df.describe()
# Out:
#         symboling  normalized-losses  ...      diesel         gas
# count  201.000000          201.00000  ...  201.000000  201.000000
# mean     0.840796          122.00000  ...    0.099502    0.900498
# std      1.254802           31.99625  ...    0.300083    0.300083
# min     -2.000000           65.00000  ...    0.000000    0.000000
# 25%      0.000000          101.00000  ...    0.000000    1.000000
# 50%      1.000000          122.00000  ...    0.000000    1.000000
# 75%      2.000000          137.00000  ...    0.000000    1.000000
# max      3.000000          256.00000  ...    1.000000    1.000000
#
# [8 rows x 19 columns]

# %% [markdown]
# #Example of describe method

# %%
sr = pd.Series([35,40,45,35,42,30,44,39,38,45,30,46])

# %%
sr.describe()
# Out:
# count    12.000000
# mean     39.083333
# std       5.648143
# min      30.000000
# 25%      35.000000
# 50%      39.500000
# 75%      44.250000
# max      46.000000
# dtype: float64

# %% [markdown]
# #Box Plot

# %%
sns.boxplot(x='num-of-cylinders', y='price', data=df)

# %% [markdown]
# #Scatter Plot

# %%
plt.scatter(df['engine-size'],df['price'])
plt.xlabel('Engine Size')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# #Histogram

# %%
count, bin_edges = np.histogram(df['peak-rpm'])
df['peak-rpm'].plot(kind='hist', xticks=bin_edges)
plt.xlabel('value of peak rpm')
plt.ylabel('Number of cars')
plt.grid()
plt.show()

# %% [markdown]
# #ANOVA(Analysis of variance)

# %%
temp_df = df[['make', 'price']].groupby(['make']) 
stats.f_oneway(temp_df.get_group('audi')['price'],temp_df.get_group('volvo')['price'])
# Out:
# F_onewayResult(statistic=0.014303241552631388, pvalue=0.9063901597143602)

# %%
stats.f_oneway(temp_df.get_group('audi')['price'],temp_df.get_group('volvo')['price'])
# Out:
# F_onewayResult(statistic=0.014303241552631388, pvalue=0.9063901597143602)

# %% [markdown]
# #Correlation

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %% [markdown]
# sns.replot(x='engine-size'), y='price', data=df

# %%
sns.regplot(x='engine-size', y='price', data=df)

# %%
sns.regplot(x='highway-mpg', y='price', data=df)
